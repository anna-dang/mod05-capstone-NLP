# %% [markdown]
# ### Hotel Review Classifier (working title)
#
# *Flatiron School Data Science Bootcamp*
#
# Captsone Project - NLP Sentiment/Ratings Analysis
#
# Anna D'Angela | [annaadangela@gmail.com](annaadangela@gmail.com)
#
# [Return to GitHub](https://github.com/anna-dang/mod05-capstone)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import Libraries
import requests
from re import compile, split
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import collection_functions as cf
import pandas as pd

# %%
domain = "https://www.tripadvisor.com"
test_page = '/Hotel_Review-g42139-d15558901-Reviews-The_Shinola_Hotel-Detroit_Michigan.html'

# Make a 'get' request to retrieve the page
html_page = requests.get(domain + test_page) 

# Pass the page contents to beautiful soup for parsing
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
# Preview the structure
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://static.tacdn.com/favicon.ico?v2" id="favicon" rel="icon" type="image/x-icon"/>
#   <link color="#000000" href="https://static.tacdn.com/img2/brand_refresh/application_icons/mask-icon.svg" rel="mask-icon" sizes="any"/>
#   <meta content="#34e0a1" name="theme-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <script type="text/javascript">
#    window.taRollupsAreAsync = true;
#   </script>
#   <link crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripSans/TripSans.css?v1.002" rel="stylesheet"/>
#   <title>
#    THE SHINOLA HOTEL - Prices &amp;  Reviews (Detroit, MI) - Tripadvisor
#   </title>
#   <meta content="TripAdvisor" property="al:ios:app_name"/>
#   <meta content="284876795" property="al:ios:app_store_id"/>
# ...

# %%
container = soup.findAll('div', class_="_2wrUUKlw _3hFEdNs8")


for item in container:
    expanded = item.find('span', class_="_1M-1YYJt")
    if expanded:
        print(expanded.text, '\n')
    else:
# Out:
#  Another thing I found interesting was the mattress.  It was like 5" thick, we both woke up with stiff backs that continued for days. Lastly was the coffee.  Seems silly right? But there is none! You seriously have to get dressed, leave the hotel, walk down the ally and pay $6 for a small coffee.  There is no coffee inside the hotel.  One of the most crazy things I've ever had to do while staying at a $400 a night hotel.  And honestly, a deal-breaker.  Who want's to do this?  No one.  Shinola!  Please, please get a $30 coffee maker for your rooms so that your guests can wake up, brew a cup, crank their heads and watch some TV.  This is honestly one of the more beautiful hotels I've ever stayed at.  But they missed on some small, yet very important details.
#
#  We had a Den King and stayed in Room 404. It was next to a small rooftop patio with grass for pets, so it’s perfect for guests traveling with pets. Overall, good size and very clean and comfortable!
#
# ...

# %%
container = soup.findAll('div', class_="_2wrUUKlw _3hFEdNs8")

page_reviews = []
page_ratings = []
page_titles = []
# looking for "ui_bubble_rating", following any value
rating_re = compile("ui_bubble_rating (.*)")

for item in container:

    # convert rating bubbles to 'int', add to list
    rating_raw = item.find('span', class_=rating_re)
    rating_int = int(rating_raw.attrs['class'][1].split("_")[1][-2])
    page_ratings.append(rating_int)

    # save all reviews on page as 'str'
    review = item.find('q', class_="IRsGHoPm").text
    
    # check for more text after "Read More" activated, complete review
    expanded = item.find('span', class_="_1M-1YYJt")
    if expanded:
        review += expanded.text
    page_reviews.append(review)

    # review title
    title = item.find('a', class_='ocfR3SKN').text
    page_titles.append(title)

# %%
for i in page_reviews:
    print(i, "\n")
# Out:
# We've been scoping out The Shinola Hotel for awhile now and finally committed to a stay.  This hotel is beautiful! Valet/Doormen/Bellmen...all that!  The ambiance is exactly what you want.  However, it misses on some CRITICAL details that just make it not worth it with so many other options available.  The Cass room has a very dramatic entrance and is amazing upon entry.  As you get acquainted, you see things are not where they should be.  Two large TV's, neither of which you can watch without turning your body 90 degrees from where you're sitting.  It's rather uncomfortable.  Same thing in the bed.  My wife and I love watching TV in bed and you had to crank your head around to see the TV.  Very odd.  If you're someone that TV doesn't matter then you would LOVE this room.  Another thing I found interesting was the mattress.  It was like 5" thick, we both woke up with stiff backs that continued for days. Lastly was the coffee.  Seems silly right? But there is none! You seriously have 
# ...

# %%
page_ratings
# Out:
# [3, 5, 3, 3, 4]

# %%
page_titles
# Out:
# ['I wanted to LOVE it so badly, swing and miss...',
#  'Excellent COVID Stay',
#  'So,so',
#  'The Detroit experience ',
#  'Unique Feel']

# %%
soup.find('div', class_="cPQsENeY")
# Out:
# <div class="cPQsENeY" style="max-height:242px">The world’s first Shinola Hotel is Detroit’s new living room. Located in the heart of the city’s historic Woodward shopping district, this 129-room boutique hotel offers a completely original hospitality experience. Shinola Hotel’s accommodations are thoughtfully designed with varied layouts—featuring handcrafted mill-work, custom mattresses, and wallpaper inspired by patterns found during the renovation process. The property marries two restored buildings—the old T.B. Rayl &amp; Co. sporting goods and hardware store and a former Singer sewing-machine store—with three brand new buildings modeled after downtown Detroit’s historic architecture. Indulge in a diverse array of culinary experiences at Shinola Hotel, featuring some of the best new restaurants in Detroit. Grab a classic cocktail in the Living Room or Evening Bar, taste the authentic Southern Italian dishes at San Morello, or try the brews and Detroit-style fried chicken at The B
# ...

# %%
# test single page gather function (each page has 5 reviews)
page_reviews, page_ratings = cf.retrieve_reviews_ratings(soup)

# %%
page_reviews
# Out:
# ["I have stayed at the siren multiple times - I adore it. Its gorgeous on every level with no detail overlooked. It's not basic - it's curated. When the outlets are open they are incredible-- I love Karl's for late night French fries, the candy bar for the coolest bar in town, lobby coffee shop is excellent. Highly recommend The Siren for anyone that appreciates style, substance and service. ",
#  'Had a great time at The Siren Hotel. The lobby is one of the most AMAZING lobbies I have ever seen, looked like it was out of a scene in The Great Gatsby. The hotel bar, The Candy Bar, is very unique place with exceptional decor, design and ambience. Great for a couple’s night out. The rooms are clean and newly renovated and furnished while maintaining the historic charm of the building. Can’t beat the location, walking distance to all of Detroit’s downtown cafes, bars and restaurants. Overall a great place for a couple to spend a weekend',
# ...

# %%
page_ratings
# Out:
# [5, 5, 5, 5, 5]

# %%
len(page_reviews) == len(page_ratings)
# Out:
# True

# %%
# test get next page
cf.get_next_page_ext(soup)

# note the '-or5' before property name, this indicates the current page counting by 5's
# Out:
# '/Hotel_Review-g42139-d13417189-Reviews-or5-The_Siren_Hotel-Detroit_Michigan.html'

# %%
# test pagination, starting at third from last page 
test_page_one = '/Hotel_Review-g42139-d13417189-Reviews-or595-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS'
reviews_1, ratings_1 = cf.parse_url(test_page_one)

# %%
reviews_1
# Out:
# ['It\'s a newly-renovated historical building turned into a hotel in the downtown. Good location. Decorations give a special vibe. I stayed at one of the rooms listed as "The Chamber". The size of the room was on the smaller side but good enough for a solo traveler. The decor of the room was really inspiring. I didn\'t get a chance to check out the candy bar but the populace coffee shop at the lobby was a delight. And to top it off, great hospitality from the polite and helpful staff made my short stay quite pleasant.',
# ...

# %%
ratings_1
# Out:
# [4, 4, 3, 5, 5]

# %%
# %%time
extension = start + str(page_num) + end
extension
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 9.78 µs

# %%
start = '/Hotel_Review-g42139-d13417189-Reviews-or'
start_page = 300
end = '-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS'

last_pages = []

for i in range(0,250,5):
    next_page = start_page + i
    extension = start + str(next_page) + end
    last_pages.append(extension)
    
last_pages
# Out:
# ['/Hotel_Review-g42139-d13417189-Reviews-or300-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or305-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or310-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or315-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or320-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or325-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or330-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or335-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or340-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or345-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
# ...

# %%
all_reviews_2 = []
all_ratings_2 = []

for page in last_pages:
    reviews, ratings = cf.parse_url(page)
    all_reviews_2.extend(reviews)
    all_ratings_2.extend(ratings)

# %%
len(all_reviews_2), len(all_ratings_2)
# Out:
# (250, 250)

# %%
# %%time
all_reviews_2[0:15]
# Out:
# CPU times: user 6 µs, sys: 16 µs, total: 22 µs
# Wall time: 25 µs
# ['We absolutely loved this hotel. The decor is amazing and the bar downstairs is the candy on top. If you want a great place to stay in Detroit, look no further than the Siren Hotel. Great location, great service, and great amenities.',
#  'Cool re-do of a classic building in a great location - across from the Opera House a few blocks from Woodward and Comerica Park - totally accessible to Q Line and all downtown.  Room was clean and felt right with a fantastic view (1209).  Liked the experience.  Lobby a bit small, but has several areas to sit - can just hang out.  Elevators are a touch slow, but feels true to the old and city noises can be heard which is nice.  Valet easy/good.  Most everyone very nice and enthusiastic.  Overall, would stay again and recommend it.',
# ...

# %% [markdown]
# # leave these to concat!

# %%
len(all_reviews)r
# Out:
# 42

# %%
len(all_ratings)
# Out:
# 42

# %%
start_url = '/Hotel_Review-g42139-d13417189-Reviews-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS'

# %%
html = requests.get(domain + hotel_pages[2])
html.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(html.content, 'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
domain = "https://www.tripadvisor.com"
start_url = '/Hotel_Review-g42139-d13417189-Reviews-The_Siren_Hotel-Detroit_Michigan.html'
 
# parse this first one and save to list    

# split URL to build next pages
url_split = start_url.split('Reviews')
url_split
# Out:
# ['/Hotel_Review-g42139-d13417189-', '-The_Siren_Hotel-Detroit_Michigan.html']

# %%
# list of page numbers for first 100 pages
get_100 = range(0,500, 5)

# 50 pages
get_50 = range(0,250, 5)
# Out:
# 51

# %%
'https://www.tripadvisor.com/Hotel_Review-g42139-d13417189-Reviews-The_Siren_Hotel-Detroit_Michigan.html'.split(domain)
# Out:
# ['',
#  '/Hotel_Review-g42139-d13417189-Reviews-The_Siren_Hotel-Detroit_Michigan.html']

# %%
# Out:
# '/Hotel_Review-g42139-d13417189-Reviews-The_Siren_Hotel-Detroit_Michigan.html'

# %%
test = cf.get_url_list(page_two, n=8)

# %%
print(len(test))
test
# Out:
# 8
# ['/Hotel_Review-g33388-d6577001-Reviews-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS',
#  '/Hotel_Review-g33388-d6577001-Reviews-or5-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS',
#  '/Hotel_Review-g33388-d6577001-Reviews-or10-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS',
#  '/Hotel_Review-g33388-d6577001-Reviews-or15-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS',
#  '/Hotel_Review-g33388-d6577001-Reviews-or20-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS',
#  '/Hotel_Review-g33388-d6577001-Reviews-or25-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS',
#  '/Hotel_Review-g33388-d6577001-Reviews-or30-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS',
#  '/Hotel_Review-g33388-d6577001-Reviews-or35-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS']

# %%
page_one = '/Hotel_Review-g42139-d13417189-Reviews-The_Siren_Hotel-Detroit_Michigan.html'
page_two = '/Hotel_Review-g33388-d6577001-Reviews-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS'
# pattern starts here
page_three = '/Hotel_Review-g42139-d13417189-Reviews-or5-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS'

# %%
middle = '/Hotel_Review-g42139-d13417189-Reviews-or340-The_Siren_Hotel-Detroit_Michigan.html'

start = '/Hotel_Review-g42139-d13417189-Reviews-or'
start_page = 50
end = '-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS'

last_pages = []

for i in range(0,250,5):
    next_page = start_page + i
    extension = start + str(next_page) + end
    last_pages.append(extension)
    
last_pages[:3]
# Out:
# ['/Hotel_Review-g42139-d13417189-Reviews-or50-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or55-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS',
#  '/Hotel_Review-g42139-d13417189-Reviews-or60-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS']

# %%
# def parse_url(start_url_ext,  location=False, reviews=[], ratings=[]):
#     """No pagination, single page
#         returns location as (hotel, city, state"""
#     root = "https://www.tripadvisor.com"
#     html = requests.get(root + start_url_ext)
#     soup = BeautifulSoup(html.content, 'html.parser')
#     page_reviews, page_ratings = retrieve_reviews_ratings(soup)
#     if location == False:
#         return page_reviews, page_ratings
#     else:
#         location = retrieve_location(soup)
#         return page_reviews, page_ratings, location



page_reviews, page_ratings, location = cf.parse_url(last_pages[2], location=True)


location
# Out:
# ('The Siren Hotel', 'Detroit', 'MI')

# %%
test_url_list
# Out:
# ['/Hotel_Review-g42139-d13417189-Reviews-or340-The_Siren_Hotel-Detroit_Michigan.html',
#  '/Hotel_Review-g42139-d13417189-Reviews-or5-or340-The_Siren_Hotel-Detroit_Michigan.html',
#  '/Hotel_Review-g42139-d13417189-Reviews-or10-or340-The_Siren_Hotel-Detroit_Michigan.html',
#  '/Hotel_Review-g42139-d13417189-Reviews-or15-or340-The_Siren_Hotel-Detroit_Michigan.html',
#  '/Hotel_Review-g42139-d13417189-Reviews-or20-or340-The_Siren_Hotel-Detroit_Michigan.html',
#  '/Hotel_Review-g42139-d13417189-Reviews-or25-or340-The_Siren_Hotel-Detroit_Michigan.html',
#  '/Hotel_Review-g42139-d13417189-Reviews-or30-or340-The_Siren_Hotel-Detroit_Michigan.html',
#  '/Hotel_Review-g42139-d13417189-Reviews-or35-or340-The_Siren_Hotel-Detroit_Michigan.html']

# %%
def parse_url_list(url_list):
    
    # returns location as ttuple (hotel, city, state)
    
    all_reviews = []
    all_ratings = []

    for idx, page in enumerate(url_list):
        # get location just once with parse of first url
        if idx == 0:
            page_one_reviews, page_one_ratings, location = cf.parse_url(page, location=True)
            all_reviews.extend(page_one_reviews)
            all_ratings.extend(page_one_ratings)
        # retrive rest of ratigns, location defaults to false
        else:    
            page_reviews, page_ratings = cf.parse_url(page)
            all_reviews.extend(reviews)
            all_ratings.extend(ratings)
    
    return all_reviews, all_ratings, location

# %%
craw = ['/Hotel_Review-g33388-d6577001-Reviews-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS']

all_reviews_mid, all_ratings_mid, location = parse_url_list(craw)

# %%
len(all_reviews_mid), location, all_ratings_mid
# Out:
# (5, ('The Crawford Hotel', 'Denver', 'CO'), [5, 5, 5, 5, 5])

# %%
make_reviews_df(all_reviews_mid, all_ratings_mid, location)
# Out:
#      Location               Hotel  \
# 0  Denver, CO  The Crawford Hotel
# 1  Denver, CO  The Crawford Hotel
# 2  Denver, CO  The Crawford Hotel
# 3  Denver, CO  The Crawford Hotel
# 4  Denver, CO  The Crawford Hotel
#
#                                               Review Rating
# 0  I've stayed at the Crawford in the past while ...      5
# 1  Visited Denver again for a family getaway. Sta...      5
# 2  Stayed one night at the B&B rate -- included v...      5
# 3  My husband and I celebrated our 25th wedding a...      5
# 4  Stayed overnight for my anniversary and was so...      5

# %%
domain = "https://www.tripadvisor.com"
test_page = '/Hotel_Review-g33388-d6577001-Reviews-or20-The_Crawford_Hotel-Denver_Colorado.html#REVIEWS'

# Make a 'get' request to retrieve the page
html_page = requests.get(domain + test_page) 

# Pass the page contents to beautiful soup for parsing
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
def retrieve_location(soup):
    # get hotel name
    hotel = soup.find(id="HEADING").text

    # get location (city/state)
    raw = soup.find('span', class_="_3ErVArsu jke2_wbp").text.split(", ")
    city = raw[-2]
    state = ''.join([i for i in raw[-1] if not i.isdigit()]).split(" -")[0]
    
    
    return (hotel, city, state)

# %%
hotel, city, state
# Out:
# ('The Crawford Hotel', 'Denver', 'CO')

# %%
location = retrieve_location(soup)
location
# Out:
# ('The Crawford Hotel', 'Denver', 'CO')

# %%
def make_reviews_df(reviews, ratings, location=None):
    """location as a tuple!!!!!!! (hotel, city, state)"""
    df = pd.DataFrame([reviews, ratings]).transpose()
    df.columns = ['Review', 'Rating']
    
    if location:
        df['Hotel'] = location[0]
        df['Location'] = location[1] + ', ' + location[2]

        # rearrange
        df = df[['Location', 'Hotel', 'Review', 'Rating']]
    
    return df

# %%
make_reviews_df(all_reviews_mid, all_ratings_mid, location)
# Out:
#       Location               Hotel  \
# 0   Denver, CO  The Crawford Hotel
# 1   Denver, CO  The Crawford Hotel
# 2   Denver, CO  The Crawford Hotel
# 3   Denver, CO  The Crawford Hotel
# 4   Denver, CO  The Crawford Hotel
# 5   Denver, CO  The Crawford Hotel
# 6   Denver, CO  The Crawford Hotel
# 7   Denver, CO  The Crawford Hotel
# 8   Denver, CO  The Crawford Hotel
# 9   Denver, CO  The Crawford Hotel
# 10  Denver, CO  The Crawford Hotel
# 11  Denver, CO  The Crawford Hotel
# 12  Denver, CO  The Crawford Hotel
# 13  Denver, CO  The Crawford Hotel
# 14  Denver, CO  The Crawford Hotel
# 15  Denver, CO  The Crawford Hotel
# 16  Denver, CO  The Crawford Hotel
# 17  Denver, CO  The Crawford Hotel
# 18  Denver, CO  The Crawford Hotel
# 19  Denver, CO  The Crawford Hotel
# 20  Denver, CO  The Crawford Hotel
# 21  Denver, CO  The Crawford Hotel
# 22  Denver, CO  The Crawford Hotel
# 23  Denver, CO  The Crawford Hotel
# 24  Denver, CO  The Crawford Hotel
# ...

# %%
shinola = '/Hotel_Review-g42139-d15558901-Reviews-or10-The_Shinola_Hotel-Detroit_Michigan.html#REVIEWS'
df = cf.scrape_hotel(shinola, n=2)
df
# Out:
#       Location              Hotel                                       Title  \
# 0  Detroit, MI  The Shinola Hotel              Birthday Trip Over to Detroit
# 1  Detroit, MI  The Shinola Hotel                                 Great vibe!
# 2  Detroit, MI  The Shinola Hotel  Spent Sunday night March 1st for a concert
# 3  Detroit, MI  The Shinola Hotel                             Concert Weekend
# 4  Detroit, MI  The Shinola Hotel           Construction Noise and Favoritism
# 5  Detroit, MI  The Shinola Hotel   Gorgeous Hotel. Mediocre Everything Else.
# 6  Detroit, MI  The Shinola Hotel                                       Great
# 7  Detroit, MI  The Shinola Hotel   Awesome room, great service, super-clean!
# 8  Detroit, MI  The Shinola Hotel                                 Thank You!!
# 9  Detroit, MI  The Shinola Hotel                              Gorgeous hotel
#
#                                               Review Rating
# ...

# %%
for item in df['Review']:
    print(item, '\n\n')
# Out:
# First let me say I love the Shinola Hotel! It’s unique to Detroit , cool and all around fabulous . I did NOT LOVE getting woken up at 7am with jackhammers from the construction site next door after being out late for my bday . It’s SUPER LOUD! Shinola you have so many great amenities provide ear plugs in room warning your guests of this noise and use them if you think you may be disturbed . My nice relaxing morning in bed to start my birthday was literally out the Window!
#
#
# I loved the hotel from the minute we walked in! Our room wasn’t ready at 4:00 when we arrived, however we were upgraded to a larger room due to the delay. Everyone was extremely friendly and the rooms are beautiful. The lobby lounge is also very attractive. I would love to stay here again.
#
#
# ...

# %%
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - There is no [mac64] chromedriver for browser 87.0.4280 in cache
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/87.0.4280.88/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/annadangela/.wdm/drivers/chromedriver/mac64/87.0.4280.88]

# %%
# per projectt??
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome(executable_path='./driver/chromedriver', options=options)

# %%
# PER PAGE!!

# get the page
domain = "https://www.tripadvisor.com"
driver.get(domain + "/Hotel_Review-g42139-d13417189-Reviews-or10-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS")

# find the 'read more' buttons        
more_buttons = driver.find_elements_by_class_name("_3maEfNCR")

#looks like only need to press the first more button to access all!!, so just press one, once pressed thtey no longer exist
if more_buttons[0].is_displayed():
    driver.execute_script("arguments[0].click();", more_buttons[0])
    sleep(1)
page_source = driver.page_source

# %%
soup = BeautifulSoup(page_source, 'html.parser')
page_reviews, page_ratings, page_titles = cf.retrieve_reviews_ratings(soup)
page_reviews
# Out:
# ['Had a wonderful stay! The staff was attentive and welcoming. It was a very chilly day and wish our room was a bit warmer, but the blankets were cozy and the shower hot! We ate at Karls and enjoyed a great sandwich and beer. We will be back!',
# ...

# %%
driver1 = cf.get_driver()

# %%
type(driver1)
# Out:
# selenium.webdriver.chrome.webdriver.WebDriver

# %%
driver1
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="84504dbc9641d24b1ab68dc962491553")>

# %%
def parse_url(start_url_ext, driver=driver, location=False):
    """No pagination, single page
        returns location as (hotel, city, state"""
    domain = "https://www.tripadvisor.com"

    # # selenium chrome driver
    # options = webdriver.ChromeOptions()
    # options.add_argument('--ignore-certificate-errors')
    # options.add_argument('--incognito')
    # options.add_argument('--headless')
    # driver = webdriver.Chrome(executable_path='./driver/chromedriver', options=options)

    # get website
    driver.get(domain + start_url_ext)

    # find the 'read more' buttons        
    more_buttons = driver.find_elements_by_class_name("_3maEfNCR")

    # ACTIVATE buttons, only need to press the first more button to access all!!, so just press one, once pressed thtey no longer exist
    if more_buttons[0].is_displayed():
        driver.execute_script("arguments[0].click();", more_buttons[0])
        sleep(1)

    # set soup    
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')

    page_reviews, page_ratings, page_titles = cf.retrieve_reviews_ratings(soup)

    # if location data requested
    if location == False:
        return page_reviews, page_ratings, page_titles
    else:
        location = cf.retrieve_location(soup)
        return page_reviews, page_ratings, page_titles, location

# %%
page_reviews, page_ratings, page_titles, location = parse_url('/Hotel_Review-g42139-d13417189-Reviews-or10-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS', driver=driver1, location=True)

# %%
page_reviews, page_ratings, page_titles, location = cf.parse_url('/Hotel_Review-g42139-d13417189-Reviews-or10-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS', driver=driver1, location=True)

# %%
page_reviews
# Out:
# ['Had a wonderful stay! The staff was attentive and welcoming. It was a very chilly day and wish our room was a bit warmer, but the blankets were cozy and the shower hot! We ate at Karls and enjoyed a great sandwich and beer. We will be back!',
# ...

# %%
location
# Out:
# ('The Siren Hotel', 'Detroit', 'MI')

# %%
df = cf.scrape_hotel('/Hotel_Review-g42139-d13417189-Reviews-or10-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS', n=2)

# %%
for i in df['Review']:
    print(i)
# Out:
# Had a wonderful stay! The staff was attentive and welcoming. It was a very chilly day and wish our room was a bit warmer, but the blankets were cozy and the shower hot! We ate at Karls and enjoyed a great sandwich and beer. We will be back!
# ...

# %%
all_reviews, all_ratings, all_titles, location = cf.parse_url_list(['/Hotel_Review-g42139-d13417189-Reviews-or15-The_Siren_Hotel-Detroit_Michigan.html#REVIEWS'])

# %%
all_reviews
# Out:
# ["This review is overdue, but I loved my 2 night stay here. Starting with the valet, he was so helpful and friendly, it started the trip off wonderfully. The Front Desk staff was also lovely, and had a warm welcome for me. The lobby is truly unique - Instagram can do all it wants, but in person is best. I really enjoyed my room, on the 10th floor with an interesting view, enough space and an amazing King size bed (I LOVE the blanket on the bed). The shower was sexy and spacious, beautifully designed. I had everything I needed in the hotel. I checked out the Candy Bar, which I am claiming as the coolest bar I have ever been too. Great vibe, unique look and delicious cocktails. I also checked out Karl's for breakfast which was PERFECT - impeccably designed with a retro look, awesome food and the staff were so friendly. A perfect hotel, in a great area, very walkable to bars/restaurants but also not a far Uber away from some other hits of Detroit. Highly, highly recommend this spot. Tha
# ...

# %%
location
# Out:
# ('The Siren Hotel', 'Detroit', 'MI')
