# %% [markdown]
# ### Hotel Review Classifier (working title)
#
# *Flatiron School Data Science Bootcamp*
#
# Captsone Project - NLP Sentiment/Ratings Analysis
#
# Anna D'Angela | [annaadangela@gmail.com](annaadangela@gmail.com)
#
# [Return to GitHub](https://github.com/anna-dang/mod05-capstone)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests
from re import compile, split
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import collection_functions as cf
import pandas as pd

# %% [markdown]
# Note: Starting with Detroit hotels to make small sample dataset to play around with/test before gather more

# %%
# list of hotel homepages url on trip advisor (page one) with how many total reviews
westin_book = '/Hotel_Review-g42139-d782678-Reviews-The_Westin_Book_Cadillac_Detroit-Detroit_Michigan.html'
siren = '/Hotel_Review-g42139-d13417189-Reviews-The_Siren_Hotel-Detroit_Michigan.html'
foundation = '/Hotel_Review-g42139-d12130393-Reviews-Detroit_Foundation_Hotel-Detroit_Michigan.html'
motorcity = '/Hotel_Review-g42139-d674740-Reviews-MotorCity_Casino_Hotel-Detroit_Michigan.html'
aloft = '/Hotel_Review-g42139-d7263062-Reviews-Aloft_Detroit_at_The_David_Whitney-Detroit_Michigan.html'

# %% [markdown]
# Testing differen page size requests to test what Trip Advisor will allow. There are 5 reviews per page. Select *n* number pages to scrape. I confirmed how many reviews per property to make sure not over pulling.

# %%
# 50 pages = 250 reviews
siren_df = cf.scrape_hotel(siren, n=50) # 610
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs

# %%
siren_df.head()
# Out:
#       Location            Hotel                              Title  \
# 0  Detroit, MI  The Siren Hotel  Absolute stunner in best location
# 1  Detroit, MI  The Siren Hotel                          Wonderful
# 2  Detroit, MI  The Siren Hotel                    Beautiful hotel
# 3  Detroit, MI  The Siren Hotel       5 stars, Best Detroit hotel!
# 4  Detroit, MI  The Siren Hotel                            Amazing
#
#                                               Review Rating
# 0  I have stayed at the siren multiple times - I ...      5
# 1  Had a great time at The Siren Hotel. The lobby...      5
# 2  The Siren hotel is located in the heart of dow...      5
# 3  Had a great time at The Siren, a building I re...      5
# 4  Great hotel,Danny at the front desk was amazin...      5

# %%
# 75 pages = 375 reviews
aloft_df = cf.scrape_hotel(aloft, n=75) # 687
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 36.7 µs

# %%
aloft_df.head()
# Out:
#       Location                               Hotel  \
# 0  Detroit, MI  Aloft Detroit at The David Whitney
# 1  Detroit, MI  Aloft Detroit at The David Whitney
# 2  Detroit, MI  Aloft Detroit at The David Whitney
# 3  Detroit, MI  Aloft Detroit at The David Whitney
# 4  Detroit, MI  Aloft Detroit at The David Whitney
#
#                                   Title  \
# 0                      Amazingly Brenda
# 1                    Christmas vacation
# 2                  Historic & Beautiful
# 3  Great stay, very accommodating staff
# 4                         Fun Work Trip
#
#                                               Review Rating
# 0  Brenda is definitely an Asset to this hotel. S...      5
# 1  the team that works at the hotel are incredibl...      5
# 2  I stayed only one night but it was memorable. ...      5
# 3  I stayed at the Aloft for four nights over the...      5
# 4  I visited the Aloft in Detroit for 5 days for ...      5

# %%
# 100 pages = 500 reviews
foundation_df = cf.scrape_hotel(foundation, n=100) # 806
foundation_df.head()
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 10 µs
#       Location                     Hotel                               Title  \
# 0  Detroit, MI  Detroit Foundation Hotel  Fantastic vacation in our own city
# 1  Detroit, MI  Detroit Foundation Hotel                          Staycation
# 2  Detroit, MI  Detroit Foundation Hotel                     A true getaway.
# 3  Detroit, MI  Detroit Foundation Hotel                 First Class Detroit
# 4  Detroit, MI  Detroit Foundation Hotel                         Very fancy!
#
#                                               Review Rating
# 0  We stayed here for one night--New Year's Eve, ...      5
# 1  Absolutely stunning place to stay between the ...      5
# 2  This was a wonderful place for a romantic geta...      5
# 3  DFH provided an excellent destination and expe...      5
# 4  Everything was very good, except for the pillo...      5

# %%
# 125 pages = 625 reviews
motorcity_df = cf.scrape_hotel(motorcity, n=125) # 1018 
motorcity_df.head()
# Out:
#       Location                   Hotel                              Title  \
# 0  Detroit, MI  MotorCity Casino Hotel  Worst first experience in Detroit
# 1  Detroit, MI  MotorCity Casino Hotel                      Nice Surprise
# 2  Detroit, MI  MotorCity Casino Hotel                      Mixed Reviews
# 3  Detroit, MI  MotorCity Casino Hotel                           Mattress
# 4  Detroit, MI  MotorCity Casino Hotel              Just ok place to stay
#
#                                               Review Rating
# 0  When we arrived the uber driver dropped us off...      1
# 1  We ended up here b/c we got a great rate for a...      4
# 2  Me and my husband went to the MotorCity Casino...      4
# 3  Please tell me what king size mattress they ha...      5
# 4  We spent a few days in Detroit and saw the rev...      3

# %%
# 150 pages = 750 reviews
westin_book_df = cf.scrape_hotel(westin_book, n=150) # 1590
westin_book_df.head()
# Out:
#       Location                             Hotel  \
# 0  Detroit, MI  The Westin Book Cadillac Detroit
# 1  Detroit, MI  The Westin Book Cadillac Detroit
# 2  Detroit, MI  The Westin Book Cadillac Detroit
# 3  Detroit, MI  The Westin Book Cadillac Detroit
# 4  Detroit, MI  The Westin Book Cadillac Detroit
#
#                                                Title  \
# 0                  Front desk service was fantastic
# 1  Terrible customer service. Answer your darn ph...
# 2                              Worked for our needs!
# 3  These people are heartless and do not care abo...
# 4                Solid hotel close to Campus Martius
#
#                                               Review Rating
# 0  My partner Eric and I come to Detroit for busi...      5
# 1  If you want your anniversary, birthday, confer...      1
# 2  Was heading to Western Michigan and needed a h...      4
# 3  I had to cancel my trip for a legitimate medic...      1
# ...

# %%
# combine all dfs
df_list = [siren_df, aloft_df, foundation_df, motorcity_df, westin_book_df]
test_df = pd.concat(df_list)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 749
# Data columns (total 5 columns):
# Location    2500 non-null object
# Hotel       2500 non-null object
# Title       2500 non-null object
# Review      2500 non-null object
# Rating      2500 non-null object
# dtypes: object(5)
# memory usage: 117.2+ KB

# %%
# save
test_df.to_csv("./data/test_data.csv", index=False)

# %%
# check
check_df = pd.read_csv("./data/test_data.csv")
check_df.head()
# Out:
#       Location            Hotel                              Title  \
# 0  Detroit, MI  The Siren Hotel  Absolute stunner in best location
# 1  Detroit, MI  The Siren Hotel                          Wonderful
# 2  Detroit, MI  The Siren Hotel                    Beautiful hotel
# 3  Detroit, MI  The Siren Hotel       5 stars, Best Detroit hotel!
# 4  Detroit, MI  The Siren Hotel                            Amazing
#
#                                               Review  Rating
# 0  I have stayed at the siren multiple times - I ...       5
# 1  Had a great time at The Siren Hotel. The lobby...       5
# 2  The Siren hotel is located in the heart of dow...       5
# 3  Had a great time at The Siren, a building I re...       5
# 4  Great hotel,Danny at the front desk was amazin...       5

# %%
# looks good!
